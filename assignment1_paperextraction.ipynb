# %%
"""
This code sample shows Custom Extraction Model operations with the Azure Form Recognizer client library. 
The async versions of the samples require Python 3.6 or later.

To learn more, please visit the documentation - Quickstart: Form Recognizer Python client library SDKs
https://docs.microsoft.com/en-us/azure/applied-ai-services/form-recognizer/quickstarts/try-v3-python-sdk
"""

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""

endpoint, key=os.getenv('PAPEREXTRACTION_ENDPOINT','PAPEREXTRACTIONKEY')
model_id = "20231110"

#a sample
pdfFile = "./sample.pdf"

document_analysis_client = DocumentAnalysisClient(
    endpoint=endpoint, credential=AzureKeyCredential(key)
)

# Make sure your document's type is included in the list of document types the custom model can analyze

with open(pdfFile, "rb") as f:
    poller = document_analysis_client.begin_analyze_document(
        "prebuilt-layout", document=f
    )
#poller = document_analysis_client.begin_analyze_document(model_id, pdfFile)
result = poller.result()

for idx, document in enumerate(result.documents):
    print("--------Analyzing document #{}--------".format(idx + 1))
    print("Document has type {}".format(document.doc_type))
    print("Document has confidence {}".format(document.confidence))
    print("Document was analyzed by model with ID {}".format(result.model_id))
    for name, field in document.fields.items():
        field_value = field.value if field.value else field.content
        print("......found field of type '{}' with value '{}' and with confidence {}".format(field.value_type, field_value, field.confidence))


# iterate over tables, lines, and selection marks on each page
for page in result.pages:
    print("\nLines found on page {}".format(page.page_number))
    for line in page.lines:
        print("...Line '{}'".format(line.content.encode('utf-8')))
    for word in page.words:
        print(
            "...Word '{}' has a confidence of {}".format(
                word.content.encode('utf-8'), word.confidence
            )
        )
    for selection_mark in page.selection_marks:
        print(
            "...Selection mark is '{}' and has a confidence of {}".format(
                selection_mark.state, selection_mark.confidence
            )
        )

for i, table in enumerate(result.tables):
    print("\nTable {} can be found on page:".format(i + 1))
    for region in table.bounding_regions:
        print("...{}".format(i + 1, region.page_number))
    for cell in table.cells:
        print(
            "...Cell[{}][{}] has content '{}'".format(
                cell.row_index, cell.column_index, cell.content.encode('utf-8')
            )
        )
print("-----------------------------------")
# Out:
# Lines found on page 1
# ...Line 'b'When Will Generative Adversarial Imitation Learning Algorithms''
# ...Line 'b'Attain Global Convergence''
# ...Line 'b'Ziwei Guan, Tengyu Xu, Yingbin Liang''
# ...Line 'b'Department of Electrical and Computer Engineering, The Ohio State University''
# ...Line 'b'{guan.283, xu.3260, liang.889} @osu.edu''
# ...Line 'b'Abstract''
# ...Line 'b'Generative adversarial imitation learning (GAIL) is a popular inverse reinforcement learning approach''
# ...Line 'b'for jointly optimizing policy and reward from expert trajectories. A primary question about GAIL is''
# ...Line 'b'whether applying a certain policy gradient algorithm to GAIL attains a global minimizer (i.e., yields the''
# ...Line 'b'expert policy), for which existing understanding is very limited. Such global convergence has been shown''
# ...Line 'b'only for the linear (or linear-type) MDP and linear (or linearizable) reward. In this paper, we study GAIL''
# ...Line 'b'under general MDP and for nonlinear reward function classes (as long as the objective function is strongly''
# ...Line 'b'concave with respect to the reward parameter). We characterize the global convergence with a sublinear''
# ...Line 'b'rate for a broad range of commonly used policy gradient algorithms, all of which are implemented in''
# ...Line 'b'an alternating manner with stochastic gradient ascent for reward update, including projected policy''
# ...Line 'b'gradient (PPG)-GAIL, Frank-Wolfe policy gradient (FWPG)-GAIL, trust region policy optimization''
# ...Line 'b'(TRPO)-GAIL and natural policy gradient (NPG)-GAIL. This is the first systematic theoretical study''
# ...Line 'b'of GAIL for global convergence.''
# ...Line 'b'arXiv:2006.13506v2 [cs.LG] 25 Jun 2020''
# ...Line 'b'1''
# ...Line 'b'Introduction''
# ...Line 'b'In reinforcement learning (RL), the reward function generally plays an important role to guide the design''
# ...Line 'b'of policy optimization to attain the best long-term accumulative reward. However, a reward function may''
# ...Line 'b'not be known in many situations, and imitation learning Osa et al. (2018) aims to find a desirable policy''
# ...Line 'b'in such cases, which produces behaviors as close as possible to expert demonstrations. Two popular classes''
# ...Line 'b'of approaches for imitation learning have been developed. The first approach is behavioral cloning (BC)''
# ...Line 'b'Pomerleau (1991), which directly provides a mapping strategy from the state space to the action space''
# ...Line 'b'based on supervised learning to match expert demonstrations. The BC method often suffers from high''
# ...Line 'b'sample complexity due to covariate shift Ross and Bagnell (2010); Ross et al. (2011) for achieving the de-''
# ...Line 'b'sired performance, which is mitigated by improved algorithms such as DAgger Ross et al. (2011) and Dart''
# ...Line 'b"Laskey et al. (2017) that require further interaction with the expert's demonstration. The second approach"'
# ...Line 'b'is the so-called inverse reinforcement learning (IRL) Ng and Russell (2000); Russell (1998), which attempts''
# ...Line 'b"to recover the unknown reward function based on the expert's trajectories, and then find an optimal policy"'
# ...Line 'b'by using such a reward function.''
# ...Line 'b'A popular IRL method has been developed in Finn et al. (2016); Fu et al. (2018); Ho and Ermon''
# ...Line 'b'(2016), which leverages the connection of IRL to the training of generative adversarial networks (GANs)''
# ...Line 'b'Goodfellow et al. (2014). In particular, the generative adversarial imitation learning (GAIL) framework''
# ...Line 'b'Ho and Ermon (2016) formulates a min-max optimization problem as in the GAN training. The maximiza-''
# ...Line 'b'tion is over the reward function (which serves as a discriminator) to best distinguish between the trajectories''
# ...Line 'b"generated by the expert and the learner, and the minimization is then over the learner's policy (which"'
# ...Line 'b"serves as a generator) to best match the expert's trajectories. Since the policy optimization in GAIL is"'
# ...Line 'b'nonconvex, its joint optimization with reward function in GAIL in general can be guaranteed to converge''
# ...Line 'b'only to a stationary point. Such a type of result was recently established in Chen et al. (2020), which stud-''
# ...Line 'b'ied GAIL under general MDP model and reward function class, and showed that the gradient-decent and''
# ...Line 'b'gradient-ascent algorithm converges to a stationary point (not necessarily the global minimum).''
# ...Line 'b'1''
# ...Word 'b'When'' has a confidence of 0.989
# ...Word 'b'Will'' has a confidence of 0.98
# ...Word 'b'Generative'' has a confidence of 0.994
# ...Word 'b'Adversarial'' has a confidence of 0.993
# ...Word 'b'Imitation'' has a confidence of 0.99
# ...Word 'b'Learning'' has a confidence of 0.99
# ...Word 'b'Algorithms'' has a confidence of 0.993
# ...Word 'b'Attain'' has a confidence of 0.995
# ...Word 'b'Global'' has a confidence of 0.995
# ...Word 'b'Convergence'' has a confidence of 0.993
# ...Word 'b'Ziwei'' has a confidence of 0.98
# ...Word 'b'Guan,'' has a confidence of 0.995
# ...Word 'b'Tengyu'' has a confidence of 0.995
# ...Word 'b'Xu,'' has a confidence of 0.995
# ...Word 'b'Yingbin'' has a confidence of 0.995
# ...Word 'b'Liang'' has a confidence of 0.995
# ...Word 'b'Department'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'Electrical'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'Computer'' has a confidence of 0.993
# ...Word 'b'Engineering,'' has a confidence of 0.974
# ...Word 'b'The'' has a confidence of 0.997
# ...Word 'b'Ohio'' has a confidence of 0.992
# ...Word 'b'State'' has a confidence of 0.994
# ...Word 'b'University'' has a confidence of 0.992
# ...Word 'b'{guan.283,'' has a confidence of 0.93
# ...Word 'b'xu.3260,'' has a confidence of 0.993
# ...Word 'b'liang.889}'' has a confidence of 0.945
# ...Word 'b'@osu.edu'' has a confidence of 0.993
# ...Word 'b'Abstract'' has a confidence of 0.995
# ...Word 'b'Generative'' has a confidence of 0.99
# ...Word 'b'adversarial'' has a confidence of 0.993
# ...Word 'b'imitation'' has a confidence of 0.993
# ...Word 'b'learning'' has a confidence of 0.994
# ...Word 'b'(GAIL)'' has a confidence of 0.966
# ...Word 'b'is'' has a confidence of 0.996
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'popular'' has a confidence of 0.995
# ...Word 'b'inverse'' has a confidence of 0.973
# ...Word 'b'reinforcement'' has a confidence of 0.993
# ...Word 'b'learning'' has a confidence of 0.994
# ...Word 'b'approach'' has a confidence of 0.995
# ...Word 'b'for'' has a confidence of 0.995
# ...Word 'b'jointly'' has a confidence of 0.994
# ...Word 'b'optimizing'' has a confidence of 0.989
# ...Word 'b'policy'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'reward'' has a confidence of 0.994
# ...Word 'b'from'' has a confidence of 0.984
# ...Word 'b'expert'' has a confidence of 0.993
# ...Word 'b'trajectories.'' has a confidence of 0.979
# ...Word 'b'A'' has a confidence of 0.933
# ...Word 'b'primary'' has a confidence of 0.951
# ...Word 'b'question'' has a confidence of 0.993
# ...Word 'b'about'' has a confidence of 0.985
# ...Word 'b'GAIL'' has a confidence of 0.99
# ...Word 'b'is'' has a confidence of 0.974
# ...Word 'b'whether'' has a confidence of 0.995
# ...Word 'b'applying'' has a confidence of 0.994
# ...Word 'b'a'' has a confidence of 0.996
# ...Word 'b'certain'' has a confidence of 0.995
# ...Word 'b'policy'' has a confidence of 0.99
# ...Word 'b'gradient'' has a confidence of 0.994
# ...Word 'b'algorithm'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'GAIL'' has a confidence of 0.991
# ...Word 'b'attains'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'global'' has a confidence of 0.995
# ...Word 'b'minimizer'' has a confidence of 0.981
# ...Word 'b'(i.e.,'' has a confidence of 0.991
# ...Word 'b'yields'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'expert'' has a confidence of 0.995
# ...Word 'b'policy),'' has a confidence of 0.961
# ...Word 'b'for'' has a confidence of 0.994
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'existing'' has a confidence of 0.994
# ...Word 'b'understanding'' has a confidence of 0.992
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'very'' has a confidence of 0.993
# ...Word 'b'limited.'' has a confidence of 0.971
# ...Word 'b'Such'' has a confidence of 0.993
# ...Word 'b'global'' has a confidence of 0.994
# ...Word 'b'convergence'' has a confidence of 0.993
# ...Word 'b'has'' has a confidence of 0.996
# ...Word 'b'been'' has a confidence of 0.993
# ...Word 'b'shown'' has a confidence of 0.995
# ...Word 'b'only'' has a confidence of 0.984
# ...Word 'b'for'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'linear'' has a confidence of 0.993
# ...Word 'b'(or'' has a confidence of 0.995
# ...Word 'b'linear-type)'' has a confidence of 0.961
# ...Word 'b'MDP'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'linear'' has a confidence of 0.991
# ...Word 'b'(or'' has a confidence of 0.995
# ...Word 'b'linearizable)'' has a confidence of 0.961
# ...Word 'b'reward.'' has a confidence of 0.993
# ...Word 'b'In'' has a confidence of 0.995
# ...Word 'b'this'' has a confidence of 0.982
# ...Word 'b'paper,'' has a confidence of 0.993
# ...Word 'b'we'' has a confidence of 0.995
# ...Word 'b'study'' has a confidence of 0.994
# ...Word 'b'GAIL'' has a confidence of 0.99
# ...Word 'b'under'' has a confidence of 0.994
# ...Word 'b'general'' has a confidence of 0.994
# ...Word 'b'MDP'' has a confidence of 0.996
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'for'' has a confidence of 0.995
# ...Word 'b'nonlinear'' has a confidence of 0.993
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'function'' has a confidence of 0.993
# ...Word 'b'classes'' has a confidence of 0.994
# ...Word 'b'(as'' has a confidence of 0.995
# ...Word 'b'long'' has a confidence of 0.992
# ...Word 'b'as'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'objective'' has a confidence of 0.993
# ...Word 'b'function'' has a confidence of 0.994
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'strongly'' has a confidence of 0.993
# ...Word 'b'concave'' has a confidence of 0.993
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'respect'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.961
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'parameter).'' has a confidence of 0.991
# ...Word 'b'We'' has a confidence of 0.998
# ...Word 'b'characterize'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'global'' has a confidence of 0.995
# ...Word 'b'convergence'' has a confidence of 0.993
# ...Word 'b'with'' has a confidence of 0.987
# ...Word 'b'a'' has a confidence of 0.961
# ...Word 'b'sublinear'' has a confidence of 0.994
# ...Word 'b'rate'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.997
# ...Word 'b'a'' has a confidence of 0.996
# ...Word 'b'broad'' has a confidence of 0.995
# ...Word 'b'range'' has a confidence of 0.982
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'commonly'' has a confidence of 0.995
# ...Word 'b'used'' has a confidence of 0.993
# ...Word 'b'policy'' has a confidence of 0.995
# ...Word 'b'gradient'' has a confidence of 0.993
# ...Word 'b'algorithms,'' has a confidence of 0.993
# ...Word 'b'all'' has a confidence of 0.995
# ...Word 'b'of'' has a confidence of 0.997
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'are'' has a confidence of 0.996
# ...Word 'b'implemented'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'an'' has a confidence of 0.995
# ...Word 'b'alternating'' has a confidence of 0.993
# ...Word 'b'manner'' has a confidence of 0.995
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'stochastic'' has a confidence of 0.994
# ...Word 'b'gradient'' has a confidence of 0.993
# ...Word 'b'ascent'' has a confidence of 0.995
# ...Word 'b'for'' has a confidence of 0.997
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'update,'' has a confidence of 0.994
# ...Word 'b'including'' has a confidence of 0.995
# ...Word 'b'projected'' has a confidence of 0.995
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'gradient'' has a confidence of 0.993
# ...Word 'b'(PPG)-GAIL,'' has a confidence of 0.982
# ...Word 'b'Frank-Wolfe'' has a confidence of 0.993
# ...Word 'b'policy'' has a confidence of 0.995
# ...Word 'b'gradient'' has a confidence of 0.995
# ...Word 'b'(FWPG)-GAIL,'' has a confidence of 0.991
# ...Word 'b'trust'' has a confidence of 0.995
# ...Word 'b'region'' has a confidence of 0.995
# ...Word 'b'policy'' has a confidence of 0.995
# ...Word 'b'optimization'' has a confidence of 0.993
# ...Word 'b'(TRPO)-GAIL'' has a confidence of 0.991
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'natural'' has a confidence of 0.994
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'gradient'' has a confidence of 0.988
# ...Word 'b'(NPG)-GAIL.'' has a confidence of 0.982
# ...Word 'b'This'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'first'' has a confidence of 0.99
# ...Word 'b'systematic'' has a confidence of 0.982
# ...Word 'b'theoretical'' has a confidence of 0.993
# ...Word 'b'study'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'GAIL'' has a confidence of 0.992
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'global'' has a confidence of 0.995
# ...Word 'b'convergence.'' has a confidence of 0.991
# ...Word 'b'arXiv:2006.13506v2'' has a confidence of 0.945
# ...Word 'b'[cs.LG]'' has a confidence of 0.932
# ...Word 'b'25'' has a confidence of 0.995
# ...Word 'b'Jun'' has a confidence of 0.995
# ...Word 'b'2020'' has a confidence of 0.992
# ...Word 'b'1'' has a confidence of 0.936
# ...Word 'b'Introduction'' has a confidence of 0.993
# ...Word 'b'In'' has a confidence of 0.994
# ...Word 'b'reinforcement'' has a confidence of 0.984
# ...Word 'b'learning'' has a confidence of 0.993
# ...Word 'b'(RL),'' has a confidence of 0.994
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'function'' has a confidence of 0.995
# ...Word 'b'generally'' has a confidence of 0.993
# ...Word 'b'plays'' has a confidence of 0.995
# ...Word 'b'an'' has a confidence of 0.967
# ...Word 'b'important'' has a confidence of 0.993
# ...Word 'b'role'' has a confidence of 0.99
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'guide'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.992
# ...Word 'b'design'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'optimization'' has a confidence of 0.987
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'attain'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'best'' has a confidence of 0.991
# ...Word 'b'long-term'' has a confidence of 0.992
# ...Word 'b'accumulative'' has a confidence of 0.973
# ...Word 'b'reward.'' has a confidence of 0.994
# ...Word 'b'However,'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.996
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'function'' has a confidence of 0.993
# ...Word 'b'may'' has a confidence of 0.996
# ...Word 'b'not'' has a confidence of 0.995
# ...Word 'b'be'' has a confidence of 0.995
# ...Word 'b'known'' has a confidence of 0.994
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'many'' has a confidence of 0.993
# ...Word 'b'situations,'' has a confidence of 0.973
# ...Word 'b'and'' has a confidence of 0.994
# ...Word 'b'imitation'' has a confidence of 0.993
# ...Word 'b'learning'' has a confidence of 0.979
# ...Word 'b'Osa'' has a confidence of 0.982
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2018)'' has a confidence of 0.993
# ...Word 'b'aims'' has a confidence of 0.992
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'find'' has a confidence of 0.978
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'desirable'' has a confidence of 0.993
# ...Word 'b'policy'' has a confidence of 0.995
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'such'' has a confidence of 0.993
# ...Word 'b'cases,'' has a confidence of 0.994
# ...Word 'b'which'' has a confidence of 0.994
# ...Word 'b'produces'' has a confidence of 0.99
# ...Word 'b'behaviors'' has a confidence of 0.993
# ...Word 'b'as'' has a confidence of 0.996
# ...Word 'b'close'' has a confidence of 0.995
# ...Word 'b'as'' has a confidence of 0.949
# ...Word 'b'possible'' has a confidence of 0.993
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'expert'' has a confidence of 0.993
# ...Word 'b'demonstrations.'' has a confidence of 0.979
# ...Word 'b'Two'' has a confidence of 0.99
# ...Word 'b'popular'' has a confidence of 0.994
# ...Word 'b'classes'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'approaches'' has a confidence of 0.994
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'imitation'' has a confidence of 0.994
# ...Word 'b'learning'' has a confidence of 0.993
# ...Word 'b'have'' has a confidence of 0.993
# ...Word 'b'been'' has a confidence of 0.993
# ...Word 'b'developed.'' has a confidence of 0.992
# ...Word 'b'The'' has a confidence of 0.997
# ...Word 'b'first'' has a confidence of 0.995
# ...Word 'b'approach'' has a confidence of 0.995
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'behavioral'' has a confidence of 0.991
# ...Word 'b'cloning'' has a confidence of 0.993
# ...Word 'b'(BC)'' has a confidence of 0.975
# ...Word 'b'Pomerleau'' has a confidence of 0.991
# ...Word 'b'(1991),'' has a confidence of 0.965
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'directly'' has a confidence of 0.993
# ...Word 'b'provides'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'mapping'' has a confidence of 0.994
# ...Word 'b'strategy'' has a confidence of 0.994
# ...Word 'b'from'' has a confidence of 0.991
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'state'' has a confidence of 0.994
# ...Word 'b'space'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'action'' has a confidence of 0.994
# ...Word 'b'space'' has a confidence of 0.995
# ...Word 'b'based'' has a confidence of 0.994
# ...Word 'b'on'' has a confidence of 0.997
# ...Word 'b'supervised'' has a confidence of 0.991
# ...Word 'b'learning'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'match'' has a confidence of 0.992
# ...Word 'b'expert'' has a confidence of 0.993
# ...Word 'b'demonstrations.'' has a confidence of 0.985
# ...Word 'b'The'' has a confidence of 0.994
# ...Word 'b'BC'' has a confidence of 0.995
# ...Word 'b'method'' has a confidence of 0.995
# ...Word 'b'often'' has a confidence of 0.994
# ...Word 'b'suffers'' has a confidence of 0.994
# ...Word 'b'from'' has a confidence of 0.993
# ...Word 'b'high'' has a confidence of 0.993
# ...Word 'b'sample'' has a confidence of 0.995
# ...Word 'b'complexity'' has a confidence of 0.994
# ...Word 'b'due'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'covariate'' has a confidence of 0.993
# ...Word 'b'shift'' has a confidence of 0.995
# ...Word 'b'Ross'' has a confidence of 0.992
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'Bagnell'' has a confidence of 0.993
# ...Word 'b'(2010);'' has a confidence of 0.995
# ...Word 'b'Ross'' has a confidence of 0.992
# ...Word 'b'et'' has a confidence of 0.961
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2011)'' has a confidence of 0.966
# ...Word 'b'for'' has a confidence of 0.997
# ...Word 'b'achieving'' has a confidence of 0.992
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'de-'' has a confidence of 0.995
# ...Word 'b'sired'' has a confidence of 0.995
# ...Word 'b'performance,'' has a confidence of 0.975
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'mitigated'' has a confidence of 0.994
# ...Word 'b'by'' has a confidence of 0.995
# ...Word 'b'improved'' has a confidence of 0.993
# ...Word 'b'algorithms'' has a confidence of 0.992
# ...Word 'b'such'' has a confidence of 0.993
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'DAgger'' has a confidence of 0.984
# ...Word 'b'Ross'' has a confidence of 0.992
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2011)'' has a confidence of 0.992
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'Dart'' has a confidence of 0.993
# ...Word 'b'Laskey'' has a confidence of 0.994
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2017)'' has a confidence of 0.985
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'require'' has a confidence of 0.994
# ...Word 'b'further'' has a confidence of 0.993
# ...Word 'b'interaction'' has a confidence of 0.993
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.981
# ...Word 'b"expert's"' has a confidence of 0.961
# ...Word 'b'demonstration.'' has a confidence of 0.992
# ...Word 'b'The'' has a confidence of 0.997
# ...Word 'b'second'' has a confidence of 0.995
# ...Word 'b'approach'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'so-called'' has a confidence of 0.982
# ...Word 'b'inverse'' has a confidence of 0.993
# ...Word 'b'reinforcement'' has a confidence of 0.982
# ...Word 'b'learning'' has a confidence of 0.993
# ...Word 'b'(IRL)'' has a confidence of 0.8
# ...Word 'b'Ng'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'Russell'' has a confidence of 0.99
# ...Word 'b'(2000);'' has a confidence of 0.961
# ...Word 'b'Russell'' has a confidence of 0.993
# ...Word 'b'(1998),'' has a confidence of 0.993
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'attempts'' has a confidence of 0.993
# ...Word 'b'to'' has a confidence of 0.98
# ...Word 'b'recover'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'unknown'' has a confidence of 0.994
# ...Word 'b'reward'' has a confidence of 0.992
# ...Word 'b'function'' has a confidence of 0.992
# ...Word 'b'based'' has a confidence of 0.995
# ...Word 'b'on'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b"expert's"' has a confidence of 0.982
# ...Word 'b'trajectories,'' has a confidence of 0.989
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'then'' has a confidence of 0.993
# ...Word 'b'find'' has a confidence of 0.992
# ...Word 'b'an'' has a confidence of 0.996
# ...Word 'b'optimal'' has a confidence of 0.994
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'by'' has a confidence of 0.997
# ...Word 'b'using'' has a confidence of 0.995
# ...Word 'b'such'' has a confidence of 0.991
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'function.'' has a confidence of 0.96
# ...Word 'b'A'' has a confidence of 0.995
# ...Word 'b'popular'' has a confidence of 0.994
# ...Word 'b'IRL'' has a confidence of 0.995
# ...Word 'b'method'' has a confidence of 0.994
# ...Word 'b'has'' has a confidence of 0.995
# ...Word 'b'been'' has a confidence of 0.992
# ...Word 'b'developed'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'Finn'' has a confidence of 0.985
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2016);'' has a confidence of 0.976
# ...Word 'b'Fu'' has a confidence of 0.994
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2018);'' has a confidence of 0.993
# ...Word 'b'Ho'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'Ermon'' has a confidence of 0.983
# ...Word 'b'(2016),'' has a confidence of 0.994
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'leverages'' has a confidence of 0.994
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'connection'' has a confidence of 0.991
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'IRL'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'training'' has a confidence of 0.992
# ...Word 'b'of'' has a confidence of 0.996
# ...Word 'b'generative'' has a confidence of 0.993
# ...Word 'b'adversarial'' has a confidence of 0.99
# ...Word 'b'networks'' has a confidence of 0.993
# ...Word 'b'(GANs)'' has a confidence of 0.992
# ...Word 'b'Goodfellow'' has a confidence of 0.993
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2014).'' has a confidence of 0.994
# ...Word 'b'In'' has a confidence of 0.995
# ...Word 'b'particular,'' has a confidence of 0.971
# ...Word 'b'the'' has a confidence of 0.994
# ...Word 'b'generative'' has a confidence of 0.993
# ...Word 'b'adversarial'' has a confidence of 0.991
# ...Word 'b'imitation'' has a confidence of 0.99
# ...Word 'b'learning'' has a confidence of 0.993
# ...Word 'b'(GAIL)'' has a confidence of 0.995
# ...Word 'b'framework'' has a confidence of 0.993
# ...Word 'b'Ho'' has a confidence of 0.995
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'Ermon'' has a confidence of 0.995
# ...Word 'b'(2016)'' has a confidence of 0.993
# ...Word 'b'formulates'' has a confidence of 0.981
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'min-max'' has a confidence of 0.994
# ...Word 'b'optimization'' has a confidence of 0.983
# ...Word 'b'problem'' has a confidence of 0.994
# ...Word 'b'as'' has a confidence of 0.985
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'GAN'' has a confidence of 0.996
# ...Word 'b'training.'' has a confidence of 0.993
# ...Word 'b'The'' has a confidence of 0.996
# ...Word 'b'maximiza-'' has a confidence of 0.992
# ...Word 'b'tion'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'over'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'function'' has a confidence of 0.994
# ...Word 'b'(which'' has a confidence of 0.995
# ...Word 'b'serves'' has a confidence of 0.993
# ...Word 'b'as'' has a confidence of 0.996
# ...Word 'b'a'' has a confidence of 0.996
# ...Word 'b'discriminator)'' has a confidence of 0.964
# ...Word 'b'to'' has a confidence of 0.997
# ...Word 'b'best'' has a confidence of 0.978
# ...Word 'b'distinguish'' has a confidence of 0.991
# ...Word 'b'between'' has a confidence of 0.994
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'trajectories'' has a confidence of 0.984
# ...Word 'b'generated'' has a confidence of 0.993
# ...Word 'b'by'' has a confidence of 0.948
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'expert'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'learner,'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'minimization'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'then'' has a confidence of 0.993
# ...Word 'b'over'' has a confidence of 0.91
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b"learner's"' has a confidence of 0.972
# ...Word 'b'policy'' has a confidence of 0.992
# ...Word 'b'(which'' has a confidence of 0.994
# ...Word 'b'serves'' has a confidence of 0.994
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'generator)'' has a confidence of 0.993
# ...Word 'b'to'' has a confidence of 0.997
# ...Word 'b'best'' has a confidence of 0.951
# ...Word 'b'match'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b"expert's"' has a confidence of 0.987
# ...Word 'b'trajectories.'' has a confidence of 0.976
# ...Word 'b'Since'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'optimization'' has a confidence of 0.988
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'GAIL'' has a confidence of 0.989
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'nonconvex,'' has a confidence of 0.991
# ...Word 'b'its'' has a confidence of 0.995
# ...Word 'b'joint'' has a confidence of 0.989
# ...Word 'b'optimization'' has a confidence of 0.991
# ...Word 'b'with'' has a confidence of 0.991
# ...Word 'b'reward'' has a confidence of 0.993
# ...Word 'b'function'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'GAIL'' has a confidence of 0.991
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.994
# ...Word 'b'can'' has a confidence of 0.996
# ...Word 'b'be'' has a confidence of 0.995
# ...Word 'b'guaranteed'' has a confidence of 0.993
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'converge'' has a confidence of 0.994
# ...Word 'b'only'' has a confidence of 0.989
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'stationary'' has a confidence of 0.983
# ...Word 'b'point.'' has a confidence of 0.994
# ...Word 'b'Such'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'type'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.997
# ...Word 'b'result'' has a confidence of 0.995
# ...Word 'b'was'' has a confidence of 0.996
# ...Word 'b'recently'' has a confidence of 0.994
# ...Word 'b'established'' has a confidence of 0.989
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'Chen'' has a confidence of 0.993
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.981
# ...Word 'b'(2020),'' has a confidence of 0.994
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'stud-'' has a confidence of 0.994
# ...Word 'b'ied'' has a confidence of 0.995
# ...Word 'b'GAIL'' has a confidence of 0.981
# ...Word 'b'under'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.993
# ...Word 'b'MDP'' has a confidence of 0.995
# ...Word 'b'model'' has a confidence of 0.948
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'function'' has a confidence of 0.962
# ...Word 'b'class,'' has a confidence of 0.979
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'showed'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'gradient-decent'' has a confidence of 0.975
# ...Word 'b'and'' has a confidence of 0.993
# ...Word 'b'gradient-ascent'' has a confidence of 0.99
# ...Word 'b'algorithm'' has a confidence of 0.995
# ...Word 'b'converges'' has a confidence of 0.993
# ...Word 'b'to'' has a confidence of 0.961
# ...Word 'b'a'' has a confidence of 0.996
# ...Word 'b'stationary'' has a confidence of 0.993
# ...Word 'b'point'' has a confidence of 0.995
# ...Word 'b'(not'' has a confidence of 0.993
# ...Word 'b'necessarily'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'global'' has a confidence of 0.993
# ...Word 'b'minimum).'' has a confidence of 0.993
# ...Word 'b'1'' has a confidence of 0.995
# ...Selection mark is 'unselected' and has a confidence of 0.1
# ...Selection mark is 'selected' and has a confidence of 0.1
# ...Selection mark is 'unselected' and has a confidence of 0.1
# ...Selection mark is 'unselected' and has a confidence of 0.1
# ...Selection mark is 'selected' and has a confidence of 0.1
# ...Selection mark is 'unselected' and has a confidence of 0.1
# ...Selection mark is 'unselected' and has a confidence of 0.1
# ...Selection mark is 'selected' and has a confidence of 0.1
# ...Selection mark is 'selected' and has a confidence of 0.1
# ...Selection mark is 'selected' and has a confidence of 0.1
#
# Lines found on page 2
# ...Line 'b'Table 1: Comparison among GAIL algorithms studied in this paper''
# ...Line 'b'Algorithms''
# ...Line 'b'Convergence rate''
# ...Line 'b'Total Complexity1,2''
# ...Line 'b'PPG-GAIL''
# ...Line 'b'01''
# ...Line 'b'1''
# ...Line 'b'(1-7)3 VT''
# ...Line 'b'\xc3\x95 (+)''
# ...Line 'b'FWPG-GAIL''
# ...Line 'b'0''
# ...Line 'b'1''
# ...Line 'b'(1-7)3 VT''
# ...Line 'b'\xc3\x95(+)''
# ...Line 'b'TRPO-GAIL (unregularized)''
# ...Line 'b'0''
# ...Line 'b'1''
# ...Line 'b'(1-2)2VT''
# ...Line 'b'TRPO-GAIL (regularized)''
# ...Line 'b'1''
# ...Line 'b'\xc3\x95''
# ...Line 'b'1''
# ...Line 'b'ST''
# ...Line 'b'\xe3\x85\x87(\xe2\x86\x93)''
# ...Line 'b'NPG-GAIL''
# ...Line 'b'-''
# ...Line 'b'0''
# ...Line 'b'1''
# ...Line 'b'(1-1)2VT''
# ...Line 'b'\xc3\x95(+)''
# ...Line 'b'1 Total complexity refers to the total number of samples needed to achieve''
# ...Line 'b'an e-accurate globally optimal point.''
# ...Line 'b'2 0(.) does not include the logarithmic terms.''
# ...Line 'b'More recently, it has been shown that some popular policy gradient algorithms Agarwal et al. (2019);''
# ...Line 'b'Liu et al. (2019); Shani et al. (2020); Wang et al. (2019); Xu et al. (2020a) can converge to a globally opti-''
# ...Line 'b'mal policy under certain policy parameterizations. Then a natural question to ask is whether such global''
# ...Line 'b'convergence continues to hold in GAIL when these algorithms are further implemented in an alternating''
# ...Line 'b'fashion with the reward optimization in GAIL. The global convergence does not necessarily hold in general,''
# ...Line 'b'because the policy optimization is still over a nonconvex objective function, which can induce complicated''
# ...Line 'b'and undesirable geometries jointly with the reward optimization as a min-max problem in GAIL. Thus, exist-''
# ...Line 'b'ing exploration on this topic in Cai et al. (2019); Zhang et al. (2020), which established global convergence''
# ...Line 'b'for GAIL, requires restrictive conditions: (1) linear (but possibly infinite dimensional) MDP and (2) linear''
# ...Line 'b'reward function or linearizable reward function such as overparameterized ReLU neural networks.''
# ...Line 'b'This paper aims to substantially expand the aforementioned global convergence results as follows.''
# ...Line 'b'. We allow general MDP models, not necessarily linear MDP. We study nonlinear reward functions as long''
# ...Line 'b'as the resulting objective function is strongly concave with respect to the reward parameter. This is a''
# ...Line 'b'much bigger class than linear reward, and is satisfied easily by incorporating a strongly concave regularizer''
# ...Line 'b'which has been commonly used in GAIL practice.''
# ...Line 'b'. In addition to the projected gradient and NPG that have been studied in Cai et al. (2019); Zhang et al.''
# ...Line 'b'(2020) for GAIL, we also study Frank-Wolfe policy gradient, which is easier to implement than projected''
# ...Line 'b'policy gradient, and TRPO which is widely adopted in GAIL in practice.''
# ...Line 'b'\xc2\xb7 Existing convergence characterization for GAIL assumed that the samples are either identical and inde-''
# ...Line 'b'pendently distributed (i.i.d.) as in Chen et al. (2020); Zhang et al. (2020) or follows the LQR dynamics''
# ...Line 'b'as in Cai et al. (2019), whereas here we assume that samples follow a general Markovian distribution.''
# ...Line 'b'1.1 Main Contributions''
# ...Line 'b'In this paper, we establish the first global convergence guarantee for GAIL under the general MDP model''
# ...Line 'b'and the nonlinear reward function class (as long as the objective function is strongly concave with respect''
# ...Line 'b'to the reward parameter). We provide the convergence rate for three major types of algorithms, all of which''
# ...Line 'b'alternate between gradient ascent (for reward update) and policy gradient descent (for policy update), re-''
# ...Line 'b'spectively being (a) projected policy gradient (PPG)-GAIL and Frank-Wolfe policy gradient (FWPG)-GAIL''
# ...Line 'b'(with direct policy parameterization); (b) trust region policy optimization (TRPO)-GAIL (with direct policy''
# ...Line 'b'parameterization); and (c) natural policy gradient (NPG)-GAIL (with general non-linear policy parameteri-''
# ...Line 'b'zation). We show that all these alternating algorithms converge to the global minimum with a sublinear rate.''
# ...Line 'b'We summarize our results on the convergence performance of the GAIL algorithms in Table 1. Comparing''
# ...Line 'b'among these algorithms indicates that TRPO-GAIL with regularized MDP achieves the best convergence''
# ...Line 'b'rate, and TRPO-GAIL with regularized and unregularized MDP outperform the other algorithms in terms''
# ...Line 'b'of the overall sample complexity.''
# ...Line 'b'2''
# ...Word 'b'Table'' has a confidence of 0.995
# ...Word 'b'1:'' has a confidence of 0.995
# ...Word 'b'Comparison'' has a confidence of 0.993
# ...Word 'b'among'' has a confidence of 0.995
# ...Word 'b'GAIL'' has a confidence of 0.993
# ...Word 'b'algorithms'' has a confidence of 0.993
# ...Word 'b'studied'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'this'' has a confidence of 0.992
# ...Word 'b'paper'' has a confidence of 0.995
# ...Word 'b'Algorithms'' has a confidence of 0.995
# ...Word 'b'Convergence'' has a confidence of 0.984
# ...Word 'b'rate'' has a confidence of 0.982
# ...Word 'b'Total'' has a confidence of 0.979
# ...Word 'b'Complexity1,2'' has a confidence of 0.982
# ...Word 'b'PPG-GAIL'' has a confidence of 0.993
# ...Word 'b'01'' has a confidence of 0.899
# ...Word 'b'1'' has a confidence of 0.995
# ...Word 'b'(1-7)3'' has a confidence of 0.653
# ...Word 'b'VT'' has a confidence of 0.592
# ...Word 'b'\xc3\x95'' has a confidence of 0.505
# ...Word 'b'(+)'' has a confidence of 0.581
# ...Word 'b'FWPG-GAIL'' has a confidence of 0.994
# ...Word 'b'0'' has a confidence of 0.582
# ...Word 'b'1'' has a confidence of 0.995
# ...Word 'b'(1-7)3'' has a confidence of 0.718
# ...Word 'b'VT'' has a confidence of 0.702
# ...Word 'b'\xc3\x95(+)'' has a confidence of 0.516
# ...Word 'b'TRPO-GAIL'' has a confidence of 0.993
# ...Word 'b'(unregularized)'' has a confidence of 0.971
# ...Word 'b'0'' has a confidence of 0.744
# ...Word 'b'1'' has a confidence of 0.996
# ...Word 'b'(1-2)2VT'' has a confidence of 0.605
# ...Word 'b'TRPO-GAIL'' has a confidence of 0.993
# ...Word 'b'(regularized)'' has a confidence of 0.973
# ...Word 'b'1'' has a confidence of 0.473
# ...Word 'b'\xc3\x95'' has a confidence of 0.639
# ...Word 'b'1'' has a confidence of 0.997
# ...Word 'b'ST'' has a confidence of 0.353
# ...Word 'b'\xe3\x85\x87'' has a confidence of 0.295
# ...Word 'b'(\xe2\x86\x93)'' has a confidence of 0.502
# ...Word 'b'NPG-GAIL'' has a confidence of 0.983
# ...Word 'b'-'' has a confidence of 0.588
# ...Word 'b'0'' has a confidence of 0.527
# ...Word 'b'1'' has a confidence of 0.996
# ...Word 'b'(1-1)2VT'' has a confidence of 0.638
# ...Word 'b'\xc3\x95(+)'' has a confidence of 0.518
# ...Word 'b'1'' has a confidence of 0.965
# ...Word 'b'Total'' has a confidence of 0.993
# ...Word 'b'complexity'' has a confidence of 0.98
# ...Word 'b'refers'' has a confidence of 0.994
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.994
# ...Word 'b'total'' has a confidence of 0.995
# ...Word 'b'number'' has a confidence of 0.994
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'samples'' has a confidence of 0.991
# ...Word 'b'needed'' has a confidence of 0.994
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'achieve'' has a confidence of 0.993
# ...Word 'b'an'' has a confidence of 0.996
# ...Word 'b'e-accurate'' has a confidence of 0.878
# ...Word 'b'globally'' has a confidence of 0.994
# ...Word 'b'optimal'' has a confidence of 0.994
# ...Word 'b'point.'' has a confidence of 0.994
# ...Word 'b'2'' has a confidence of 0.527
# ...Word 'b'0(.)'' has a confidence of 0.715
# ...Word 'b'does'' has a confidence of 0.989
# ...Word 'b'not'' has a confidence of 0.995
# ...Word 'b'include'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.991
# ...Word 'b'logarithmic'' has a confidence of 0.992
# ...Word 'b'terms.'' has a confidence of 0.992
# ...Word 'b'More'' has a confidence of 0.993
# ...Word 'b'recently,'' has a confidence of 0.991
# ...Word 'b'it'' has a confidence of 0.995
# ...Word 'b'has'' has a confidence of 0.995
# ...Word 'b'been'' has a confidence of 0.993
# ...Word 'b'shown'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'some'' has a confidence of 0.993
# ...Word 'b'popular'' has a confidence of 0.961
# ...Word 'b'policy'' has a confidence of 0.993
# ...Word 'b'gradient'' has a confidence of 0.986
# ...Word 'b'algorithms'' has a confidence of 0.992
# ...Word 'b'Agarwal'' has a confidence of 0.992
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2019);'' has a confidence of 0.993
# ...Word 'b'Liu'' has a confidence of 0.995
# ...Word 'b'et'' has a confidence of 0.975
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2019);'' has a confidence of 0.995
# ...Word 'b'Shani'' has a confidence of 0.994
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2020);'' has a confidence of 0.97
# ...Word 'b'Wang'' has a confidence of 0.993
# ...Word 'b'et'' has a confidence of 0.996
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2019);'' has a confidence of 0.995
# ...Word 'b'Xu'' has a confidence of 0.995
# ...Word 'b'et'' has a confidence of 0.928
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2020a)'' has a confidence of 0.994
# ...Word 'b'can'' has a confidence of 0.995
# ...Word 'b'converge'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.997
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'globally'' has a confidence of 0.993
# ...Word 'b'opti-'' has a confidence of 0.995
# ...Word 'b'mal'' has a confidence of 0.996
# ...Word 'b'policy'' has a confidence of 0.995
# ...Word 'b'under'' has a confidence of 0.995
# ...Word 'b'certain'' has a confidence of 0.994
# ...Word 'b'policy'' has a confidence of 0.993
# ...Word 'b'parameterizations.'' has a confidence of 0.987
# ...Word 'b'Then'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.996
# ...Word 'b'natural'' has a confidence of 0.995
# ...Word 'b'question'' has a confidence of 0.994
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'ask'' has a confidence of 0.996
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'whether'' has a confidence of 0.995
# ...Word 'b'such'' has a confidence of 0.993
# ...Word 'b'global'' has a confidence of 0.995
# ...Word 'b'convergence'' has a confidence of 0.994
# ...Word 'b'continues'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.997
# ...Word 'b'hold'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'GAIL'' has a confidence of 0.993
# ...Word 'b'when'' has a confidence of 0.993
# ...Word 'b'these'' has a confidence of 0.988
# ...Word 'b'algorithms'' has a confidence of 0.994
# ...Word 'b'are'' has a confidence of 0.997
# ...Word 'b'further'' has a confidence of 0.995
# ...Word 'b'implemented'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'an'' has a confidence of 0.997
# ...Word 'b'alternating'' has a confidence of 0.952
# ...Word 'b'fashion'' has a confidence of 0.994
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'reward'' has a confidence of 0.99
# ...Word 'b'optimization'' has a confidence of 0.992
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'GAIL.'' has a confidence of 0.983
# ...Word 'b'The'' has a confidence of 0.997
# ...Word 'b'global'' has a confidence of 0.995
# ...Word 'b'convergence'' has a confidence of 0.991
# ...Word 'b'does'' has a confidence of 0.992
# ...Word 'b'not'' has a confidence of 0.995
# ...Word 'b'necessarily'' has a confidence of 0.991
# ...Word 'b'hold'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'general,'' has a confidence of 0.99
# ...Word 'b'because'' has a confidence of 0.984
# ...Word 'b'the'' has a confidence of 0.994
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'optimization'' has a confidence of 0.989
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'still'' has a confidence of 0.995
# ...Word 'b'over'' has a confidence of 0.993
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'nonconvex'' has a confidence of 0.992
# ...Word 'b'objective'' has a confidence of 0.993
# ...Word 'b'function,'' has a confidence of 0.992
# ...Word 'b'which'' has a confidence of 0.993
# ...Word 'b'can'' has a confidence of 0.993
# ...Word 'b'induce'' has a confidence of 0.993
# ...Word 'b'complicated'' has a confidence of 0.982
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'undesirable'' has a confidence of 0.992
# ...Word 'b'geometries'' has a confidence of 0.993
# ...Word 'b'jointly'' has a confidence of 0.994
# ...Word 'b'with'' has a confidence of 0.988
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'reward'' has a confidence of 0.994
# ...Word 'b'optimization'' has a confidence of 0.992
# ...Word 'b'as'' has a confidence of 0.994
# ...Word 'b'a'' has a confidence of 0.996
# ...Word 'b'min-max'' has a confidence of 0.994
# ...Word 'b'problem'' has a confidence of 0.995
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'GAIL.'' has a confidence of 0.963
# ...Word 'b'Thus,'' has a confidence of 0.993
# ...Word 'b'exist-'' has a confidence of 0.994
# ...Word 'b'ing'' has a confidence of 0.996
# ...Word 'b'exploration'' has a confidence of 0.984
# ...Word 'b'on'' has a confidence of 0.997
# ...Word 'b'this'' has a confidence of 0.993
# ...Word 'b'topic'' has a confidence of 0.995
# ...Word 'b'in'' has a confidence of 0.993
# ...Word 'b'Cai'' has a confidence of 0.995
# ...Word 'b'et'' has a confidence of 0.996
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2019);'' has a confidence of 0.962
# ...Word 'b'Zhang'' has a confidence of 0.995
# ...Word 'b'et'' has a confidence of 0.996
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2020),'' has a confidence of 0.994
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'established'' has a confidence of 0.993
# ...Word 'b'global'' has a confidence of 0.994
# ...Word 'b'convergence'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.995
# ...Word 'b'GAIL,'' has a confidence of 0.993
# ...Word 'b'requires'' has a confidence of 0.982
# ...Word 'b'restrictive'' has a confidence of 0.987
# ...Word 'b'conditions:'' has a confidence of 0.971
# ...Word 'b'(1)'' has a confidence of 0.993
# ...Word 'b'linear'' has a confidence of 0.993
# ...Word 'b'(but'' has a confidence of 0.993
# ...Word 'b'possibly'' has a confidence of 0.992
# ...Word 'b'infinite'' has a confidence of 0.988
# ...Word 'b'dimensional)'' has a confidence of 0.975
# ...Word 'b'MDP'' has a confidence of 0.996
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'(2)'' has a confidence of 0.995
# ...Word 'b'linear'' has a confidence of 0.992
# ...Word 'b'reward'' has a confidence of 0.983
# ...Word 'b'function'' has a confidence of 0.993
# ...Word 'b'or'' has a confidence of 0.996
# ...Word 'b'linearizable'' has a confidence of 0.99
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'function'' has a confidence of 0.993
# ...Word 'b'such'' has a confidence of 0.993
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'overparameterized'' has a confidence of 0.979
# ...Word 'b'ReLU'' has a confidence of 0.989
# ...Word 'b'neural'' has a confidence of 0.995
# ...Word 'b'networks.'' has a confidence of 0.993
# ...Word 'b'This'' has a confidence of 0.993
# ...Word 'b'paper'' has a confidence of 0.994
# ...Word 'b'aims'' has a confidence of 0.992
# ...Word 'b'to'' has a confidence of 0.973
# ...Word 'b'substantially'' has a confidence of 0.987
# ...Word 'b'expand'' has a confidence of 0.992
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'aforementioned'' has a confidence of 0.988
# ...Word 'b'global'' has a confidence of 0.995
# ...Word 'b'convergence'' has a confidence of 0.992
# ...Word 'b'results'' has a confidence of 0.993
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'follows.'' has a confidence of 0.992
# ...Word 'b'.'' has a confidence of 0.604
# ...Word 'b'We'' has a confidence of 0.995
# ...Word 'b'allow'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.993
# ...Word 'b'MDP'' has a confidence of 0.993
# ...Word 'b'models,'' has a confidence of 0.992
# ...Word 'b'not'' has a confidence of 0.995
# ...Word 'b'necessarily'' has a confidence of 0.985
# ...Word 'b'linear'' has a confidence of 0.994
# ...Word 'b'MDP.'' has a confidence of 0.991
# ...Word 'b'We'' has a confidence of 0.994
# ...Word 'b'study'' has a confidence of 0.994
# ...Word 'b'nonlinear'' has a confidence of 0.992
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'functions'' has a confidence of 0.993
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'long'' has a confidence of 0.992
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'resulting'' has a confidence of 0.983
# ...Word 'b'objective'' has a confidence of 0.991
# ...Word 'b'function'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'strongly'' has a confidence of 0.982
# ...Word 'b'concave'' has a confidence of 0.994
# ...Word 'b'with'' has a confidence of 0.991
# ...Word 'b'respect'' has a confidence of 0.993
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.994
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'parameter.'' has a confidence of 0.973
# ...Word 'b'This'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'much'' has a confidence of 0.993
# ...Word 'b'bigger'' has a confidence of 0.995
# ...Word 'b'class'' has a confidence of 0.994
# ...Word 'b'than'' has a confidence of 0.993
# ...Word 'b'linear'' has a confidence of 0.995
# ...Word 'b'reward,'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'is'' has a confidence of 0.996
# ...Word 'b'satisfied'' has a confidence of 0.993
# ...Word 'b'easily'' has a confidence of 0.961
# ...Word 'b'by'' has a confidence of 0.996
# ...Word 'b'incorporating'' has a confidence of 0.989
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'strongly'' has a confidence of 0.995
# ...Word 'b'concave'' has a confidence of 0.995
# ...Word 'b'regularizer'' has a confidence of 0.992
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'has'' has a confidence of 0.996
# ...Word 'b'been'' has a confidence of 0.993
# ...Word 'b'commonly'' has a confidence of 0.995
# ...Word 'b'used'' has a confidence of 0.992
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'GAIL'' has a confidence of 0.991
# ...Word 'b'practice.'' has a confidence of 0.961
# ...Word 'b'.'' has a confidence of 0.599
# ...Word 'b'In'' has a confidence of 0.995
# ...Word 'b'addition'' has a confidence of 0.993
# ...Word 'b'to'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'projected'' has a confidence of 0.973
# ...Word 'b'gradient'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.995
# ...Word 'b'NPG'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'have'' has a confidence of 0.993
# ...Word 'b'been'' has a confidence of 0.992
# ...Word 'b'studied'' has a confidence of 0.993
# ...Word 'b'in'' has a confidence of 0.982
# ...Word 'b'Cai'' has a confidence of 0.995
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.994
# ...Word 'b'(2019);'' has a confidence of 0.995
# ...Word 'b'Zhang'' has a confidence of 0.995
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.994
# ...Word 'b'(2020)'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.995
# ...Word 'b'GAIL,'' has a confidence of 0.994
# ...Word 'b'we'' has a confidence of 0.996
# ...Word 'b'also'' has a confidence of 0.987
# ...Word 'b'study'' has a confidence of 0.995
# ...Word 'b'Frank-Wolfe'' has a confidence of 0.993
# ...Word 'b'policy'' has a confidence of 0.995
# ...Word 'b'gradient,'' has a confidence of 0.993
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'is'' has a confidence of 0.996
# ...Word 'b'easier'' has a confidence of 0.994
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'implement'' has a confidence of 0.993
# ...Word 'b'than'' has a confidence of 0.993
# ...Word 'b'projected'' has a confidence of 0.993
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'gradient,'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'TRPO'' has a confidence of 0.992
# ...Word 'b'which'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'widely'' has a confidence of 0.994
# ...Word 'b'adopted'' has a confidence of 0.994
# ...Word 'b'in'' has a confidence of 0.98
# ...Word 'b'GAIL'' has a confidence of 0.99
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'practice.'' has a confidence of 0.976
# ...Word 'b'\xc2\xb7'' has a confidence of 0.569
# ...Word 'b'Existing'' has a confidence of 0.994
# ...Word 'b'convergence'' has a confidence of 0.993
# ...Word 'b'characterization'' has a confidence of 0.991
# ...Word 'b'for'' has a confidence of 0.995
# ...Word 'b'GAIL'' has a confidence of 0.992
# ...Word 'b'assumed'' has a confidence of 0.994
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'samples'' has a confidence of 0.994
# ...Word 'b'are'' has a confidence of 0.996
# ...Word 'b'either'' has a confidence of 0.995
# ...Word 'b'identical'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'inde-'' has a confidence of 0.994
# ...Word 'b'pendently'' has a confidence of 0.992
# ...Word 'b'distributed'' has a confidence of 0.968
# ...Word 'b'(i.i.d.)'' has a confidence of 0.932
# ...Word 'b'as'' has a confidence of 0.996
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'Chen'' has a confidence of 0.992
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2020);'' has a confidence of 0.993
# ...Word 'b'Zhang'' has a confidence of 0.995
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2020)'' has a confidence of 0.993
# ...Word 'b'or'' has a confidence of 0.995
# ...Word 'b'follows'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'LQR'' has a confidence of 0.995
# ...Word 'b'dynamics'' has a confidence of 0.993
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'in'' has a confidence of 0.995
# ...Word 'b'Cai'' has a confidence of 0.995
# ...Word 'b'et'' has a confidence of 0.995
# ...Word 'b'al.'' has a confidence of 0.995
# ...Word 'b'(2019),'' has a confidence of 0.993
# ...Word 'b'whereas'' has a confidence of 0.995
# ...Word 'b'here'' has a confidence of 0.961
# ...Word 'b'we'' has a confidence of 0.995
# ...Word 'b'assume'' has a confidence of 0.99
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'samples'' has a confidence of 0.995
# ...Word 'b'follow'' has a confidence of 0.994
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'general'' has a confidence of 0.995
# ...Word 'b'Markovian'' has a confidence of 0.993
# ...Word 'b'distribution.'' has a confidence of 0.987
# ...Word 'b'1.1'' has a confidence of 0.994
# ...Word 'b'Main'' has a confidence of 0.988
# ...Word 'b'Contributions'' has a confidence of 0.987
# ...Word 'b'In'' has a confidence of 0.995
# ...Word 'b'this'' has a confidence of 0.992
# ...Word 'b'paper,'' has a confidence of 0.993
# ...Word 'b'we'' has a confidence of 0.997
# ...Word 'b'establish'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'first'' has a confidence of 0.993
# ...Word 'b'global'' has a confidence of 0.994
# ...Word 'b'convergence'' has a confidence of 0.973
# ...Word 'b'guarantee'' has a confidence of 0.99
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'GAIL'' has a confidence of 0.991
# ...Word 'b'under'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.961
# ...Word 'b'general'' has a confidence of 0.993
# ...Word 'b'MDP'' has a confidence of 0.995
# ...Word 'b'model'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'nonlinear'' has a confidence of 0.993
# ...Word 'b'reward'' has a confidence of 0.994
# ...Word 'b'function'' has a confidence of 0.993
# ...Word 'b'class'' has a confidence of 0.993
# ...Word 'b'(as'' has a confidence of 0.995
# ...Word 'b'long'' has a confidence of 0.992
# ...Word 'b'as'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'objective'' has a confidence of 0.993
# ...Word 'b'function'' has a confidence of 0.993
# ...Word 'b'is'' has a confidence of 0.995
# ...Word 'b'strongly'' has a confidence of 0.993
# ...Word 'b'concave'' has a confidence of 0.995
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'respect'' has a confidence of 0.992
# ...Word 'b'to'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'parameter).'' has a confidence of 0.984
# ...Word 'b'We'' has a confidence of 0.997
# ...Word 'b'provide'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'convergence'' has a confidence of 0.993
# ...Word 'b'rate'' has a confidence of 0.993
# ...Word 'b'for'' has a confidence of 0.996
# ...Word 'b'three'' has a confidence of 0.994
# ...Word 'b'major'' has a confidence of 0.994
# ...Word 'b'types'' has a confidence of 0.993
# ...Word 'b'of'' has a confidence of 0.997
# ...Word 'b'algorithms,'' has a confidence of 0.993
# ...Word 'b'all'' has a confidence of 0.996
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'which'' has a confidence of 0.995
# ...Word 'b'alternate'' has a confidence of 0.994
# ...Word 'b'between'' has a confidence of 0.995
# ...Word 'b'gradient'' has a confidence of 0.994
# ...Word 'b'ascent'' has a confidence of 0.995
# ...Word 'b'(for'' has a confidence of 0.988
# ...Word 'b'reward'' has a confidence of 0.995
# ...Word 'b'update)'' has a confidence of 0.994
# ...Word 'b'and'' has a confidence of 0.998
# ...Word 'b'policy'' has a confidence of 0.995
# ...Word 'b'gradient'' has a confidence of 0.994
# ...Word 'b'descent'' has a confidence of 0.995
# ...Word 'b'(for'' has a confidence of 0.993
# ...Word 'b'policy'' has a confidence of 0.995
# ...Word 'b'update),'' has a confidence of 0.993
# ...Word 'b're-'' has a confidence of 0.995
# ...Word 'b'spectively'' has a confidence of 0.991
# ...Word 'b'being'' has a confidence of 0.995
# ...Word 'b'(a)'' has a confidence of 0.987
# ...Word 'b'projected'' has a confidence of 0.991
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'gradient'' has a confidence of 0.992
# ...Word 'b'(PPG)-GAIL'' has a confidence of 0.981
# ...Word 'b'and'' has a confidence of 0.993
# ...Word 'b'Frank-Wolfe'' has a confidence of 0.984
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'gradient'' has a confidence of 0.99
# ...Word 'b'(FWPG)-GAIL'' has a confidence of 0.961
# ...Word 'b'(with'' has a confidence of 0.994
# ...Word 'b'direct'' has a confidence of 0.994
# ...Word 'b'policy'' has a confidence of 0.993
# ...Word 'b'parameterization);'' has a confidence of 0.949
# ...Word 'b'(b)'' has a confidence of 0.961
# ...Word 'b'trust'' has a confidence of 0.993
# ...Word 'b'region'' has a confidence of 0.993
# ...Word 'b'policy'' has a confidence of 0.981
# ...Word 'b'optimization'' has a confidence of 0.983
# ...Word 'b'(TRPO)-GAIL'' has a confidence of 0.979
# ...Word 'b'(with'' has a confidence of 0.956
# ...Word 'b'direct'' has a confidence of 0.992
# ...Word 'b'policy'' has a confidence of 0.994
# ...Word 'b'parameterization);'' has a confidence of 0.961
# ...Word 'b'and'' has a confidence of 0.997
# ...Word 'b'(c)'' has a confidence of 0.995
# ...Word 'b'natural'' has a confidence of 0.994
# ...Word 'b'policy'' has a confidence of 0.995
# ...Word 'b'gradient'' has a confidence of 0.983
# ...Word 'b'(NPG)-GAIL'' has a confidence of 0.995
# ...Word 'b'(with'' has a confidence of 0.993
# ...Word 'b'general'' has a confidence of 0.994
# ...Word 'b'non-linear'' has a confidence of 0.99
# ...Word 'b'policy'' has a confidence of 0.995
# ...Word 'b'parameteri-'' has a confidence of 0.989
# ...Word 'b'zation).'' has a confidence of 0.993
# ...Word 'b'We'' has a confidence of 0.997
# ...Word 'b'show'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.993
# ...Word 'b'all'' has a confidence of 0.996
# ...Word 'b'these'' has a confidence of 0.992
# ...Word 'b'alternating'' has a confidence of 0.993
# ...Word 'b'algorithms'' has a confidence of 0.994
# ...Word 'b'converge'' has a confidence of 0.995
# ...Word 'b'to'' has a confidence of 0.997
# ...Word 'b'the'' has a confidence of 0.997
# ...Word 'b'global'' has a confidence of 0.994
# ...Word 'b'minimum'' has a confidence of 0.995
# ...Word 'b'with'' has a confidence of 0.992
# ...Word 'b'a'' has a confidence of 0.995
# ...Word 'b'sublinear'' has a confidence of 0.993
# ...Word 'b'rate.'' has a confidence of 0.995
# ...Word 'b'We'' has a confidence of 0.996
# ...Word 'b'summarize'' has a confidence of 0.993
# ...Word 'b'our'' has a confidence of 0.997
# ...Word 'b'results'' has a confidence of 0.993
# ...Word 'b'on'' has a confidence of 0.996
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'convergence'' has a confidence of 0.989
# ...Word 'b'performance'' has a confidence of 0.992
# ...Word 'b'of'' has a confidence of 0.997
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'GAIL'' has a confidence of 0.991
# ...Word 'b'algorithms'' has a confidence of 0.987
# ...Word 'b'in'' has a confidence of 0.996
# ...Word 'b'Table'' has a confidence of 0.995
# ...Word 'b'1.'' has a confidence of 0.993
# ...Word 'b'Comparing'' has a confidence of 0.981
# ...Word 'b'among'' has a confidence of 0.995
# ...Word 'b'these'' has a confidence of 0.995
# ...Word 'b'algorithms'' has a confidence of 0.993
# ...Word 'b'indicates'' has a confidence of 0.993
# ...Word 'b'that'' has a confidence of 0.983
# ...Word 'b'TRPO-GAIL'' has a confidence of 0.986
# ...Word 'b'with'' has a confidence of 0.993
# ...Word 'b'regularized'' has a confidence of 0.985
# ...Word 'b'MDP'' has a confidence of 0.994
# ...Word 'b'achieves'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.995
# ...Word 'b'best'' has a confidence of 0.993
# ...Word 'b'convergence'' has a confidence of 0.991
# ...Word 'b'rate,'' has a confidence of 0.993
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'TRPO-GAIL'' has a confidence of 0.992
# ...Word 'b'with'' has a confidence of 0.98
# ...Word 'b'regularized'' has a confidence of 0.991
# ...Word 'b'and'' has a confidence of 0.996
# ...Word 'b'unregularized'' has a confidence of 0.993
# ...Word 'b'MDP'' has a confidence of 0.993
# ...Word 'b'outperform'' has a confidence of 0.993
# ...Word 'b'the'' has a confidence of 0.99
# ...Word 'b'other'' has a confidence of 0.993
# ...Word 'b'algorithms'' has a confidence of 0.994
# ...Word 'b'in'' has a confidence of 0.997
# ...Word 'b'terms'' has a confidence of 0.991
# ...Word 'b'of'' has a confidence of 0.995
# ...Word 'b'the'' has a confidence of 0.996
# ...Word 'b'overall'' has a confidence of 0.993
# ...Word 'b'sample'' has a confidence of 0.995
# ...Word 'b'complexity.'' has a confidence of 0.981
# ...Word 'b'2'' has a confidence of 0.996
#
# Table 1 can be found on page:
# ...1
# ...Cell[0][0] has content 'b'Algorithms''
# ...Cell[0][1] has content 'b'Convergence rate''
# ...Cell[0][2] has content 'b'Total Complexity1,2''
# ...Cell[1][0] has content 'b'PPG-GAIL''
# ...Cell[1][1] has content 'b'01 1 (1-7)3 VT''
# ...Cell[1][2] has content 'b'\xc3\x95 (+)''
# ...Cell[2][0] has content 'b'FWPG-GAIL''
# ...Cell[2][1] has content 'b'0 1 (1-7)3 VT''
# ...Cell[2][2] has content 'b'\xc3\x95(+)''
# ...Cell[3][0] has content 'b'TRPO-GAIL (unregularized)''
# ...Cell[3][1] has content 'b'0 1 (1-2)2VT''
# ...Cell[3][2] has content 'b'''
# ...Cell[4][0] has content 'b'TRPO-GAIL (regularized)''
# ...Cell[4][1] has content 'b'1 \xc3\x95 1 ST''
# ...Cell[4][2] has content 'b'\xe3\x85\x87(\xe2\x86\x93)''
# ...Cell[5][0] has content 'b'NPG-GAIL''
# ...Cell[5][1] has content 'b'- 0 1 (1-1)2VT''
# ...Cell[5][2] has content 'b'\xc3\x95(+)''
# -----------------------------------
