# %%
import azure.cognitiveservices.speech as speechsdk
import os
import time
import wave
import string

speech_key, service_region=os.getenv('SPEECH_SERVICE_KEY'),"eastus"
print(speech_key,service_region)
speech_config=speechsdk.SpeechConfig(subscription=speech_key,region=service_region)

#Replace with the path to your audio file
#audio_file='./BillGates_2010.wav'
audio_file=r"./BillGates_2010.wav"

#creates an audio configuration that points to an audio file
audio_config=speechsdk.audio.AudioConfig(filename=audio_file)
#creates a recognizer with the given settings
speech_recognizer=speechsdk.SpeechRecognizer(speech_config=speech_config,audio_config=audio_config)
#speech_recognizer=speechsdk.transcription.ConversationTranscriber(speech_config=speech_config, audio_config=audio_config)
print("Recognizing speech from file...")

global done
done=False
def stop_cb(evt):
     """Callback that signals to stop continuous recognition upon receiving an evnt 'evt"""
     print('CLOSING on {}'.format(evt))

     done=True
# Connect callbacks to the events fired by the speech recognizer
speech_recognizer.recognizing.connect(lambda evt: print('RECOGNIZING: {}'.format(evt)))
speech_recognizer.recognized.connect(lambda evt: print('RECOGNIZED: {}'.format(evt)))
speech_recognizer.session_started.connect(lambda evt: print('SESSION STARTED: {}'.format(evt)))
speech_recognizer.session_stopped.connect(lambda evt: print('SESSION STOPPED {}'.format(evt)))
speech_recognizer.canceled.connect(lambda evt: print('CANCELED {}'.format(evt)))
# stop continuous recognition on either session stopped or canceled events
speech_recognizer.session_stopped.connect(stop_cb)
speech_recognizer.canceled.connect(stop_cb)

# Start continuous speech recognition
speech_recognizer.start_continuous_recognition()
while not done:
    time.sleep(.5)

speech_recognizer.stop_continuous_recognition()
"""speech_recognition_result=speech_recognizer.start_continuous_recognition()
print(speech_recognition_result)

if speech_recognition_result.reason == speechsdk.ResultReason.RecognizedSpeech:
        print("Recognized: {}".format(speech_recognition_result.text))
elif speech_recognition_result.reason == speechsdk.ResultReason.NoMatch:
    print("No speech could be recognized: {}".format(speech_recognition_result.no_match_details))
elif speech_recognition_result.reason == speechsdk.ResultReason.Canceled:
    cancellation_details = speech_recognition_result.cancellation_details
    print("Speech Recognition canceled: {}".format(cancellation_details.reason))
    if cancellation_details.reason == speechsdk.CancellationReason.Error:
        print("Error details: {}".format(cancellation_details.error_details))
        print("Did you set the speech resource key and region values?")
print(speech_recognition_result.text)"""
# Out:
# f6b8b9ac381741d98af5a2ae7a57f09f eastus
# Recognizing speech from file...
# SESSION STARTED: SessionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34)
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=6a6fdf899d0041a7b579cc40fc7a683c, text="", reason=ResultReason.NoMatch))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=14d1712d0ce1474d917d173d6ecca1b9, text="i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=dc4bf306621b4cdab8424b64f72048df, text="i'm going to talk", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=a233148ae6e7474eb8e0e0e76e9b91bb, text="i'm going to talk today", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=2484cbf830e143a4a93238c8fd9c5f89, text="i'm going to talk today about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=2f17165b10b54ab0b3356cdb993c6b96, text="i'm going to talk today about energy", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=16dbe0f1c9eb49adabda6f2c73e5ceb9, text="i'm going to talk today about energy and climate", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=62dce878865d4695b41e9b3bc9762430, text="i'm going to talk today about energy and climate and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=9fa821d20237426b95ae9c44a630c797, text="i'm going to talk today about energy and climate and that might", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=33e04b3ae35d4be19d9bcc2ed0167482, text="i'm going to talk today about energy and climate and that might seem", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=6b5178b3f2d34939bc0609f019a81145, text="i'm going to talk today about energy and climate and that might seem a bit", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=f775ee98c0d84307a3cccc21df92422d, text="i'm going to talk today about energy and climate and that might seem a bit surprising", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=2b37427c28574b6e83ac8ef55c10143f, text="i'm going to talk today about energy and climate and that might seem a bit surprising because", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=657a25016e8a4fcb8701ef6d601941f1, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=c49adba2aa944676a52c5edb3a451430, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=0f956ed58808476e90009225af85f709, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=d1ef36f60d074fa9afe1359895958621, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=024093f49dc04c1385315b6257ea47a8, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=f81c1d971a2f40488d6c740600fb41cc, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=fb82aa04fd114f398d2aff89eca0a0a5, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=439b0f05fd0343ab9948797af0c3d7b2, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=393d2760249c4210949ae0b7fe5eb270, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=792170f7f32040bca248a09a8f02d023, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=2a36acd32b8f48298d803637a67bbfc2, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=6ad7a72a532b4609a496efd79ef934b6, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=3d17b317d95e461fb3d9c20e5bc9ca20, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=49dcc59458a24f95879aec4af4ca5564, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=927cb67578834df99badfb9dbc9ebe64, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=f9871b640c3240a29d55a31a13cbed1b, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=0f4c7f656a10474b98293422bbc08048, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to invent", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=aa2aa2448baa4bed950694bd1a60af5b, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to invent and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=6bf40a7bc8604e3fa263032f4f8010a3, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to invent and deliver", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=38e00a18630d4c4f905966d9716f341a, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to invent and deliver to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=500ecce1a7ec4a6cb0f630f6488a3815, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to invent and deliver to help", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=98a7e7561c6e4d6398d1ca352bca3a10, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to invent and deliver to help the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=818ef5affcdb45958014dd4b82b54190, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to invent and deliver to help the poorest", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=28ed0fbf4375481fa372ad7fb1e588ee, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to invent and deliver to help the poorest 2", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=5cc72e4f328147988b41ebad6faa748b, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to invent and deliver to help the poorest 2 billion", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=ef8ebc8e83d04b05a793cd23e94d2569, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to invent and deliver to help the poorest 2 billion live better", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=fae407960d1f4d629d77df13c5a390ef, text="i'm going to talk today about energy and climate and that might seem a bit surprising because my full time work at the foundation is mostly about vaccines and seeds about the things that we need to invent and deliver to help the poorest 2 billion live better lives", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=d04c2f3e67d84baf94dba2c83ff10de2, text="I'm going to talk today about energy and climate, and that might seem a bit surprising because my full time work at the Foundation is mostly about vaccines and seeds, about the things that we need to invent and deliver to help the poorest 2 billion live better lives.", reason=ResultReason.RecognizedSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=f50e3a1d77dd4085b74162667cf85a9f, text="but", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=14603d5115fd4a278025b44e62914e48, text="but energy", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=764301c31eaf4554aff70071c8949807, text="but energy and climate", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=01bc1d786d104f248cc5611d75e87537, text="but energy and climate are", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=9844fb32557d4acd9049062c95ebf42b, text="but energy and climate are extremely", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=058e1c4a75f24ceebc4434532e09522f, text="but energy and climate are extremely important", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=1165b2f1d9f048558d4c3cae8c1565ea, text="but energy and climate are extremely important to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=7250a357500248c1ba683e7ecd87a148, text="but energy and climate are extremely important to these", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=2296db0c040142d2900242c237c5c368, text="but energy and climate are extremely important to these people", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=372e7668a2f9412eb44fa5e2d1884cb6, text="but energy and climate are extremely important to these people in fact", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=ced612f73a524d01b279bfe8416a79b7, text="but energy and climate are extremely important to these people in fact more", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=22edbe316c2148119068fe6f9dce6d12, text="but energy and climate are extremely important to these people in fact more important", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=cf3a0b1faee34be79fb9a7945617409d, text="but energy and climate are extremely important to these people in fact more important than", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=4e03f5e47b614bbbb519cb1c52075597, text="but energy and climate are extremely important to these people in fact more important than to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=b8e8c49ce6a841bcae66004013ac1b65, text="but energy and climate are extremely important to these people in fact more important than to anyone", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=cf8c1923de13431095cad3bb0bd14798, text="but energy and climate are extremely important to these people in fact more important than to anyone else", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=3cd462903145422087013079022d6f69, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=cd79c4d757d44aed92ba976f12bed242, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=3de6f4d294cf4a178342cbd6a1e61c1c, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=4c344ddf655c4557b39bfd7f384ea5fa, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=d22b2e1c0da74e82a51c2653147f7097, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=e5b20adc54164575b0fb46d4b6cc2b97, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=65836394edaa460cadd8b17b6c51e9c7, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=40211ad247374a5eacaab14fe5aa0b31, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=ead3ff79a2314ad094ed212153585299, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=b5a29685c6734f0ab7f4b0dddc4bca14, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=d4b8a3458bde434b9859c67caa2989be, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crop", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=59e5a7a4f44b46ecbac116a682ad6c4f, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=7c9ef21a32014592bcc371a301d4f36b, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=30707e7527a949878de91a3046c9e2b3, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=efc58aae5ad540faa1e006cc2b8078c0, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=3c63df7d76174f808e47b74f575e1b1f, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=8870e1d1ced348368861cf452ce687da, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=245c0a40e9524e6784460c93f44f305d, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=fb841f88fdc54d69882af2a78ca2bfe1, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=7754329cf61a4b14a85a099865e6cbc4, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=16fc40146aa64e2693c84249cf190930, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=48d88b8bb41a4c43be54297e575891b4, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=61c3bb8167bd45cd99934740f9b03097, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=423236ead96944c497caa34f4e3a94d0, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=62955ebb5c34413197d4c87c791eac9d, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environ", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=475a577df7f94e539c0d163c9fdcd63b, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=5c5279f3a2a34d75984f82060e9168b8, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=17a717c8e69e43ad91c62926a79f33a8, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=1a241721d5664ad5bb5f26710b6f2ed4, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=d0a5409fe1a844a5bcce5582fdca305c, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=73b1edc5df7d469f89ffcd108735e286, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=5b37d1a522ab4fa0a815b857152b3663, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=e2a7dde92e534e659b31bc82abb54747, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation it", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=ea8e125a11a548cfad2a14ef6e74764d, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation it leads to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=6a727a65788e460d9cfef80ac542ed8b, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation it leads to uncertainty", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=7a89c7d9962149939ec1efa47bc8f5e6, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation it leads to uncertainty it", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=a72d12203c4341ddb657bc4afe486c7e, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation it leads to uncertainty it leads to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=c60412bfc0a54593b8db90b3d8230fd0, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation it leads to uncertainty it leads to unrest", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=09b70b079b22410091f6f9cd1a21f5fa, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation it leads to uncertainty it leads to unrest so", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=019c406962df4f1d923e84078ca42904, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation it leads to uncertainty it leads to unrest so the the climate", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=54f93a9e368c43869a181845226a2c27, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation it leads to uncertainty it leads to unrest so the the climate changes", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=e3c84a58bb51469ab3a2303a9199dc4c, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation it leads to uncertainty it leads to unrest so the the climate changes will be terrible", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=3bf9c58c7cfa40a18a8c6bbca01fbfea, text="but energy and climate are extremely important to these people in fact more important than to anyone else on the planet the climate getting worse means that many years their crops won't grow there'll be too much rain not enough rain things will change in ways that their fragile environment simply can't support and that leads to starvation it leads to uncertainty it leads to unrest so the the climate changes will be terrible for them", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=a933d5e7626f48d988fdb05b49b613a0, text="But energy and climate are extremely important to these people, in fact more important than to anyone else on the planet. The climate getting worse means that many years their crops won't grow, there'll be too much rain, not enough rain. Things will change in ways that their fragile environment simply can't support. And that leads to starvation, that leads to uncertainty, it leads to unrest. So the the climate changes will be terrible for them.", reason=ResultReason.RecognizedSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=f2148734dd97429ab20ff350f156b87c, text="also", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=12749c77e7f5461dad256637e8720c1e, text="also the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=0779d58c72bd4f6f949256666f478538, text="also the price", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=c759dee9cebe41f1b803766a8c5c0591, text="also the price of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=9380b4ffe2b34645966b7dd90f70c085, text="also the price of energy is", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=93715143201c4384aa1bbe82fde35f0e, text="also the price of energy is very important to them", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=1ce0e91da25c438cb4ec8d1e3c107b9d, text="also the price of energy is very important to them in fact", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=c81f4f15d9f34a9abc699c6089bb3aa3, text="also the price of energy is very important to them in fact if", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=9d5058a001784ba8aaa9ffacee82aa97, text="also the price of energy is very important to them in fact if you could", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=795adc523a5942b29bb8835205ac87e3, text="also the price of energy is very important to them in fact if you could pick just", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=fec75a1b4e2948b28bff9457f120aadb, text="also the price of energy is very important to them in fact if you could pick just one thing", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=3f4810cace8943f4ba3b65b808a7af08, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=1ca2b20b695e4cb98ab4f9419ef8aab0, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=2345a62c619441668408f1bc80ebf334, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=a795e036b11c4791a47b0e5e433b45e4, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=cdf2012aedd34f5e9c2b05a3407c1d96, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce poverty", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=94c886db85e74b1ca2aaa30b322add19, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce poverty by far", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=1206b2a26a904b329c7c03f4011156db, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce poverty by far you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=5ce4e57385874b91bf06644cd47826c3, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce poverty by far you would pick", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=b22037aa5cf948da8157b7c081399351, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce poverty by far you would pick energy", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=1066afea8d5f44c48ea22da4249d7124, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce poverty by far you would pick energy now", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=53f3e1f3d1d449298127485982680c2e, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce poverty by far you would pick energy now the price of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=43b26284b4a84b98955cd03ed46522b1, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce poverty by far you would pick energy now the price of energy", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=d3c14892a1eb4360baf769eeb9b7114e, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce poverty by far you would pick energy now the price of energy has come", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=73672f2cca6140de9a647e4461fc5eab, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce poverty by far you would pick energy now the price of energy has come down", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=c4487bf5473f4cb9a36c5c8e08189549, text="also the price of energy is very important to them in fact if you could pick just one thing to lower the price of to reduce poverty by far you would pick energy now the price of energy has come down over", reason=ResultReason.RecognizingSpeech))
# ...
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=f8ab8db74cf9440db49a0fc0ec0edb3e, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=04a18eafdb814a1bb22b5b4a6a754405, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=2c4f99fa8af34892a581f710de854354, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=51e492e188a64f6fb6810c22d22f6cfe, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=7acb2161a6344bb5b46a91c476a019b8, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at T", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=bf59d0e5e29d458cae86bc54c1ee0261, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at ted people", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=7f1f05239be241208f477e82748733f6, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at ted people are", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=bfd3b3d8f8b146319cfb9db5e260a01a, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at ted people are putting", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=8b1386c2c4e347ada9b86f2aeebafdea, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at ted people are putting words", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=fa37eeb82acc4ea8b8f1398774737981, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at ted people are putting words together", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=13921183cf944fcca5a06324c246d360, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at ted people are putting words together in", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=18d6c351125b428b9c06138c03a41718, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at ted people are putting words together in pairs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=38cf8d292a2a45cfa39629691d61149a, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at ted people are putting words together in pairs because", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=9b9208b1fd8e41eba3b5a971df7f6b25, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at ted people are putting words together in pairs because they understand", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=266eee9c3bb6444fbff6ce7cb3fab7c7, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at ted people are putting words together in pairs because they understand the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=bdf5deb13aec4d06804a70b99d7811b8, text="people are playing with words it's it's true all week long people have been putting words together in very unique ways i've been thinking about how food and wine are paired by experts who really understand the flavors and here at ted people are putting words together in pairs because they understand the meaning", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=6de87fa6602946edabf36a816bba27c0, text="People are playing with words. It's it's true. All week long people have been putting words together in very unique ways. I've been thinking about how food and wine are paired by experts who really understand the flavors. And here at Ted, people are putting words together in pairs because they understand the meaning.", reason=ResultReason.RecognizedSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=7a4e5114159c4a499928bbccdce1eb71, text="reckless", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=284c4b3acf7d4c03b7b365db1a43e3ea, text="reckless creativity", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=7ca469555ce34a68b1c2f7eef3ab89bb, text="reckless creativity what", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=77add6eb6cd6452da23e9ab941437cbd, text="reckless creativity what a pairing that is", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=fdc0b48af82c42619bc13491f09c8977, text="Reckless creativity. What a pairing that is.", reason=ResultReason.RecognizedSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=eda77a504d4345a7aabdd81da77df294, text="just thinking", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=eb362ba53d264e129ec5de08c94b00bb, text="just thinking about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=2a23b26528b94247a61405e33ebf7c05, text="just thinking about words", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=9e8a53a78b3b4218a9ebca40348b54f8, text="just thinking about words that", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=f23b49b3527845ef91e84e135d70cc06, text="just thinking about words that don't go", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=92fa6b08db7140e3aeee21bf7d0e083b, text="just thinking about words that don't go together", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=0107adcfd75f40bb8dbd8134d18b64b4, text="just thinking about words that don't go together where one", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=9b8a2056f23a42c3805ea703fee0f361, text="just thinking about words that don't go together where one and one", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=d691dfbe219246ac83b147ec7e9d54c9, text="just thinking about words that don't go together where one and one equal", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=f23ee26e696a4d5eb7a8560cfcec8c9a, text="just thinking about words that don't go together where one and one equal 3", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=9de5043ba2504369a6f79894c15c2a27, text="Just thinking about words that don't go together where one and one equal 3.", reason=ResultReason.RecognizedSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=820b27eab8a14500b82e701fa22c4b3e, text="i think that's", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=b54d17a36ad9416684ac4fb784e2dec4, text="i think that's what", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=f499a454e1404fb5913e61329f572c4c, text="i think that's what ted's all about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=38343eab73f74a49bea0e5944d5321a7, text="i think that's what ted's all about isn't", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=cf1d1fb4f36e4d7c9ade9e4081f5984f, text="i think that's what ted's all about isn't is just", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=97caf7ca7fa54af7a1c2a6c0832f4a65, text="i think that's what ted's all about isn't is just putting", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=52aec06f37ff45c29176a2acb9d21d81, text="i think that's what ted's all about isn't is just putting things", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=833a66cfde3e48a2a1abc1c0a4ae0430, text="i think that's what ted's all about isn't is just putting things together", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=e08346e6259a40f0974afd51d87618f7, text="i think that's what ted's all about isn't is just putting things together we don't", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=296749d49f384069aec692d727cb4304, text="i think that's what ted's all about isn't is just putting things together we don't normally", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=a99bead5b4414bd5ac11261eef56afe1, text="i think that's what ted's all about isn't is just putting things together we don't normally think of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=b0adea34bde04bafbf7a5a34615df684, text="I think that's what Ted's all about, isn't. It's just putting things together we don't normally think.", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=7af399f237cd4475bec528986802d5bb, text="", reason=ResultReason.NoMatch))
# CANCELED SpeechRecognitionCanceledEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=835f5a6e7a3043daa716f6e633e04583, text="", reason=ResultReason.Canceled))
# CLOSING on SpeechRecognitionCanceledEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34, result=SpeechRecognitionResult(result_id=835f5a6e7a3043daa716f6e633e04583, text="", reason=ResultReason.Canceled))
# SESSION STOPPED SessionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34)
# CLOSING on SessionEventArgs(session_id=3dc05a1bf2e145f5a9fcb496868a2b34)

# %%
import azure.cognitiveservices.speech as speechsdk
import os
import time
import wave
import string

speech_key, service_region=os.getenv('SPEECH_SERVICE_KEY'),"eastus"
print(speech_key,service_region)
speech_config=speechsdk.SpeechConfig(subscription=speech_key,region=service_region)
speech_config.speech_recognition_language="en-US"
#Replace with the path to your audio file
#audio_file='./BillGates_2010.wav'
audio_file=r"E:\维多利亚\Louis Openai\BillGates_2010.wav"

#creates an audio configuration that points to an audio file
audio_config=speechsdk.audio.AudioConfig(filename=audio_file)
#creates a recognizer with the given settings
#speech_recognizer=speechsdk.SpeechRecognizer(speech_config=speech_config,audio_config=audio_config)

conversation_transcriber = speechsdk.transcription.ConversationTranscriber(speech_config=speech_config, audio_config=audio_config)
print(conversation_transcriber.start_transcribing_async())
result=conversation_transcriber.stop_transcribing_async()

print (result.ConversationTranscriptionResult)
# Out:
# f6b8b9ac381741d98af5a2ae7a57f09f eastus
# <azure.cognitiveservices.speech.ResultFuture object at 0x0000025C829481C0>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\维多利亚\Louis Openai\assignment1_audio_analysis.ipynb Cell 2 line 2
#      <a href='vscode-notebook-cell:/e%3A/%E7%BB%B4%E5%A4%9A%E5%88%A9%E4%BA%9A/Louis%20Openai/assignment1_audio_analysis.ipynb#W1sZmlsZQ%3D%3D?line=20'>21</a> print(conversation_transcriber.start_transcribing_async())
#      <a href='vscode-notebook-cell:/e%3A/%E7%BB%B4%E5%A4%9A%E5%88%A9%E4%BA%9A/Louis%20Openai/assignment1_audio_analysis.ipynb#W1sZmlsZQ%3D%3D?line=21'>22</a> result=conversation_transcriber.stop_transcribing_async()
# ---> <a href='vscode-notebook-cell:/e%3A/%E7%BB%B4%E5%A4%9A%E5%88%A9%E4%BA%9A/Louis%20Openai/assignment1_audio_analysis.ipynb#W1sZmlsZQ%3D%3D?line=23'>24</a> print (result.ConversationTranscriptionResult)
#
# AttributeError: 'ResultFuture' object has no attribute 'ConversationTranscriptionResult'
